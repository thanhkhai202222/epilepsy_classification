# %%
import numpy as np
import mne
import os
import pandas as pd

# %%
def process_edf_features(edf_file_path, output_csv_path):
    raw = mne.io.read_raw_edf(edf_file_path, preload=True)

    # Select only odd-numbered channels (1st, 3rd, 5th, etc.)
    odd_channels = raw.get_data()[0::2, :]  # Start at index 0 and take every second channel (0-based index)

    # Compute average signal
    sum_signal = np.sum(odd_channels, axis=0)
    avg_signal = sum_signal / odd_channels.shape[0]
    # Convert the avg_signal array to a DataFrame with each element in a separate column
    df = pd.DataFrame([avg_signal], columns=[f"Time_{i}" for i in range(avg_signal.shape[0])])
    # Add a label column with "epilepsy"
    df['Label'] = 'epilepsy'
    # Save the DataFrame to a CSV file
    df.to_csv("avg_signal.csv", index=False)

# %%
path = "process_epilepsy_20to24"
output_dir = "4channels20to25.csv"

# Loop through all EDF files in the directory
for filename in os.listdir(path):
    if filename.endswith('.edf'):
        input_dir = os.path.join(path, filename)
        
        # Process the file and extract features
        process_edf_features(input_dir, output_dir)
        
    print(f"Processed: {input_dir}")

# %%
epilepsy = "process_epilepsy_11to13/aaaaaanr_s007_t004.edf"

# %%
import numpy as np
import mne


raw = mne.io.read_raw_edf(epilepsy, preload=True)

# Select only odd-numbered channels (1st, 3rd, 5th, etc.)
odd_channels = raw.get_data()[0::2, :]  # Start at index 0 and take every second channel (0-based index)

# Compute average signal
sum_signal = np.sum(odd_channels, axis=0)
avg_signal = sum_signal / odd_channels.shape[0]

avg_signal
# Convert the avg_signal array to a DataFrame with each element in a separate column
df = pd.DataFrame([avg_signal], columns=[f"Time_{i}" for i in range(avg_signal.shape[0])])
# Add a label column with "epilepsy"
df['Label'] = 'epilepsy'
# Save the DataFrame to a CSV file
df.to_csv("avg_signal.csv", index=False)
# Out:
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_11to13\aaaaaanr_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 198911  =      0.000 ...   776.996 secs...

# %%
def process_edf_files(edf_files, output_csv):
    all_data = []
    max_length = 0  # To store the maximum length across all files
    
    # Process each EDF file
    for file in edf_files:
        raw = mne.io.read_raw_edf(file, preload=True)
        odd_channels = raw.get_data()[0::2, :]  # Select odd-numbered channels
        avg_signal = np.mean(odd_channels, axis=0)  # Compute average signal
        
        # Update max_length if this file has more time points
        if avg_signal.shape[0] > max_length:
            max_length = avg_signal.shape[0]
        
        all_data.append(avg_signal)
    
    # Create a DataFrame where each row corresponds to an EDF file
    df = pd.DataFrame()
    for i, data in enumerate(all_data):
        row_data = np.pad(data, (0, max_length - data.shape[0]), 'constant', constant_values=np.nan)  # Pad shorter rows with NaN
        df_row = pd.DataFrame([row_data], columns=[f"Time_{j}" for j in range(max_length)])
        df_row['Label'] = 'epilepsy'  # Add label column
        df = pd.concat([df, df_row], ignore_index=True)
    
    # Save to CSV
    df.to_csv(output_csv, index=False)
    print(f"Data has been saved to {output_csv}")

# %%
path = "process_epilepsy_20to24"
output_dir = "test.csv"

# Loop through all EDF files in the directory
for filename in os.listdir(path):
    if filename.endswith('.edf'):
        input_dir = os.path.join(path, filename)
        
        # Process the file and extract features
        process_edf_files(input_dir, output_dir)
        
    print(f"Processed: {input_dir}")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[12], line 10
#       7     input_dir = os.path.join(path, filename)
#       9     # Process the file and extract features
# ---> 10     process_edf_files(input_dir, output_dir)
#      12 print(f"Processed: {input_dir}")
#
# Cell In[11], line 7, in process_edf_files(edf_files, output_csv)
#       5 # Process each EDF file
#       6 for file in edf_files:
# ----> 7     raw = mne.io.read_raw_edf(file, preload=True)
#       8     odd_channels = raw.get_data()[0::2, :]  # Select odd-numbered channels
#       9     avg_signal = np.mean(odd_channels, axis=0)  # Compute average signal
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\edf\edf.py:1674, in read_raw_edf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, verbose)
#    1672 ext = os.path.splitext(input_fname)[1][1:].lower()
#    1673 if ext != "edf":
# -> 1674     raise NotImplementedError(f"Only EDF files are supported, got {ext}.")
#    1675 return RawEDF(
#    1676     input_fname=input_fname,
#    1677     eog=eog,
#    (...)
#    1686     verbose=verbose,
#    1687 )
#
# NotImplementedError: Only EDF files are supported, got .

# %%
def process_single_edf(file, output_csv):
    raw = mne.io.read_raw_edf(file, preload=True)
    
    # Select odd-numbered channels (1st, 3rd, 5th, etc.)
    odd_channels = raw.get_data()[0::2, :]  # Take odd-numbered channels (0-based index)
    odd_channels = raw.get_data()[1::2, :]  # even
    
    # Compute average signal
    avg_signal = np.mean(odd_channels, axis=0)

    # Create a DataFrame for this file
    df = pd.DataFrame([avg_signal], columns=[f"Time_{i}" for i in range(avg_signal.shape[0])])
    
    # Add a label column with "epilepsy"
    df['Label'] = 'epilepsy'
    
    # Save the DataFrame to a CSV file
    df.to_csv(output_csv, mode='a', header=not os.path.exists(output_csv), index=False)  # Append to CSV

    print(f"Processed file: {file}")

# %%
path = "process_epilepsy_20to24_2"
output_csv = "test2.csv"

# Loop through all EDF files in the directory
for filename in os.listdir(path):
    if filename.endswith('.edf'):
        input_file = os.path.join(path, filename)
        
        # Process the file and extract features
        process_single_edf(input_file, output_csv)

    print(f"Processed: {filename}")
# Out:
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakoq_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 346749  =      0.000 ...  1386.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakoq_s004_t000.edf
# Processed: aaaaakoq_s004_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakoq_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 324249  =      0.000 ...  1296.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakoq_s010_t001.edf
# Processed: aaaaakoq_s010_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakoq_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 308991  =      0.000 ...  1206.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakoq_s011_t000.edf
# Processed: aaaaakoq_s011_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqa_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300749  =      0.000 ...  1202.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqa_s001_t000.edf
# Processed: aaaaakqa_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqa_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301999  =      0.000 ...  1207.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqa_s002_t000.edf
# Processed: aaaaakqa_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqa_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 349999  =      0.000 ...  1399.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqa_s003_t000.edf
# Processed: aaaaakqa_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqa_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1493999  =      0.000 ...  1493.999 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqa_s004_t000.edf
# Processed: aaaaakqa_s004_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqq_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 364249  =      0.000 ...  1456.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqq_s001_t001.edf
# Processed: aaaaakqq_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqq_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300999  =      0.000 ...  1203.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqq_s002_t000.edf
# Processed: aaaaakqq_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqq_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 357749  =      0.000 ...  1430.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqq_s003_t000.edf
# Processed: aaaaakqq_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqq_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 354999  =      0.000 ...  1419.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqq_s004_t001.edf
# Processed: aaaaakqq_s004_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakqq_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 321999  =      0.000 ...  1287.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakqq_s005_t000.edf
# Processed: aaaaakqq_s005_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaktn_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 313249  =      0.000 ...  1252.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaktn_s001_t001.edf
# Processed: aaaaaktn_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaktn_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 355749  =      0.000 ...  1422.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaktn_s002_t000.edf
# Processed: aaaaaktn_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakvr_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 367999  =      0.000 ...  1471.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakvr_s001_t000.edf
# Processed: aaaaakvr_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaakyc_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 322999  =      0.000 ...  1291.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaakyc_s001_t001.edf
# Processed: aaaaakyc_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalfg_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 313343  =      0.000 ...  1223.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalfg_s003_t001.edf
# Processed: aaaaalfg_s003_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalfg_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 307199  =      0.000 ...  1199.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalfg_s004_t000.edf
# Processed: aaaaalfg_s004_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalfg_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 307199  =      0.000 ...  1199.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalfg_s004_t001.edf
# Processed: aaaaalfg_s004_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalfg_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 330749  =      0.000 ...  1322.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalfg_s007_t000.edf
# Processed: aaaaalfg_s007_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalgi_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 365749  =      0.000 ...  1462.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalgi_s001_t001.edf
# Processed: aaaaalgi_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalhr_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 319749  =      0.000 ...  1278.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalhr_s001_t000.edf
# Processed: aaaaalhr_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalib_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 310249  =      0.000 ...  1240.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalib_s001_t000.edf
# Processed: aaaaalib_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalib_s008_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 327249  =      0.000 ...  1308.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalib_s008_t001.edf
# Processed: aaaaalib_s008_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalib_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 323249  =      0.000 ...  1292.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalib_s009_t000.edf
# Processed: aaaaalib_s009_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalim_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 345499  =      0.000 ...  1381.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalim_s001_t001.edf
# Processed: aaaaalim_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalim_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 309247  =      0.000 ...  1207.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalim_s010_t000.edf
# Processed: aaaaalim_s010_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalim_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 302249  =      0.000 ...  1208.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalim_s011_t000.edf
# Processed: aaaaalim_s011_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalim_s012_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 297999  =      0.000 ...  1191.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalim_s012_t001.edf
# Processed: aaaaalim_s012_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaliw_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 312499  =      0.000 ...  1249.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaliw_s001_t001.edf
# Processed: aaaaaliw_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaliw_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300249  =      0.000 ...  1200.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaliw_s002_t000.edf
# Processed: aaaaaliw_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaliw_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 302499  =      0.000 ...  1209.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaliw_s003_t000.edf
# Processed: aaaaaliw_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalof_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301499  =      0.000 ...  1205.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalof_s001_t000.edf
# Processed: aaaaalof_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalon_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 307499  =      0.000 ...  1229.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalon_s002_t000.edf
# Processed: aaaaalon_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalqm_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 361249  =      0.000 ...  1444.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalqm_s001_t000.edf
# Processed: aaaaalqm_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalqm_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 302999  =      0.000 ...  1211.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalqm_s002_t000.edf
# Processed: aaaaalqm_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalqm_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 341249  =      0.000 ...  1364.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalqm_s003_t002.edf
# Processed: aaaaalqm_s003_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalug_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300999  =      0.000 ...  1203.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalug_s001_t000.edf
# Processed: aaaaalug_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalug_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 345249  =      0.000 ...  1380.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalug_s002_t001.edf
# Processed: aaaaalug_s002_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaluq_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 303999  =      0.000 ...  1215.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaluq_s002_t000.edf
# Processed: aaaaaluq_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalzg_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301249  =      0.000 ...  1204.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalzg_s001_t000.edf
# Processed: aaaaalzg_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalzg_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 346499  =      0.000 ...  1385.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalzg_s002_t000.edf
# Processed: aaaaalzg_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalzg_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 310249  =      0.000 ...  1240.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalzg_s005_t000.edf
# Processed: aaaaalzg_s005_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalzg_s008_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 315903  =      0.000 ...  1233.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalzg_s008_t000.edf
# Processed: aaaaalzg_s008_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalzg_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 307999  =      0.000 ...  1231.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalzg_s009_t000.edf
# Processed: aaaaalzg_s009_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaalzg_s018_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 337749  =      0.000 ...  1350.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaalzg_s018_t000.edf
# Processed: aaaaalzg_s018_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamde_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 317499  =      0.000 ...  1269.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamde_s001_t001.edf
# Processed: aaaaamde_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamde_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 344249  =      0.000 ...  1376.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamde_s002_t001.edf
# Processed: aaaaamde_s002_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamde_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 363749  =      0.000 ...  1454.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamde_s003_t000.edf
# Processed: aaaaamde_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamde_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 376999  =      0.000 ...  1507.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamde_s004_t000.edf
# Processed: aaaaamde_s004_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamde_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1310999  =      0.000 ...  1310.999 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamde_s007_t000.edf
# Processed: aaaaamde_s007_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamgc_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300249  =      0.000 ...  1200.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamgc_s001_t001.edf
# Processed: aaaaamgc_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamgc_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 363999  =      0.000 ...  1455.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamgc_s002_t000.edf
# Processed: aaaaamgc_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamhb_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 320249  =      0.000 ...  1280.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamhb_s003_t000.edf
# Processed: aaaaamhb_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamhb_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300749  =      0.000 ...  1202.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamhb_s005_t000.edf
# Processed: aaaaamhb_s005_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamic_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301999  =      0.000 ...  1207.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamic_s002_t000.edf
# Processed: aaaaamic_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamkx_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 362749  =      0.000 ...  1450.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamkx_s001_t000.edf
# Processed: aaaaamkx_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamlf_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 304999  =      0.000 ...  1219.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamlf_s001_t001.edf
# Processed: aaaaamlf_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamlm_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 311749  =      0.000 ...  1246.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamlm_s001_t000.edf
# Processed: aaaaamlm_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamnj_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 362249  =      0.000 ...  1448.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamnj_s001_t000.edf
# Processed: aaaaamnj_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamoa_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 315499  =      0.000 ...  1261.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamoa_s001_t000.edf
# Processed: aaaaamoa_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamoa_s008_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 360749  =      0.000 ...  1442.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamoa_s008_t000.edf
# Processed: aaaaamoa_s008_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamor_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301749  =      0.000 ...  1206.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamor_s001_t000.edf
# Processed: aaaaamor_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamrq_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 303749  =      0.000 ...  1214.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamrq_s001_t000.edf
# Processed: aaaaamrq_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamsw_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 298249  =      0.000 ...  1192.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamsw_s001_t001.edf
# Processed: aaaaamsw_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamsw_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 360499  =      0.000 ...  1441.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamsw_s002_t000.edf
# Processed: aaaaamsw_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamsw_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 366249  =      0.000 ...  1464.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamsw_s003_t000.edf
# Processed: aaaaamsw_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamtl_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 304249  =      0.000 ...  1216.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamtl_s001_t000.edf
# Processed: aaaaamtl_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamtl_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 353999  =      0.000 ...  1415.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamtl_s002_t000.edf
# Processed: aaaaamtl_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamuy_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 314749  =      0.000 ...  1258.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamuy_s001_t000.edf
# Processed: aaaaamuy_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamuy_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 302999  =      0.000 ...  1211.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamuy_s002_t000.edf
# Processed: aaaaamuy_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamuy_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301999  =      0.000 ...  1207.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamuy_s003_t000.edf
# Processed: aaaaamuy_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamuy_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300499  =      0.000 ...  1201.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamuy_s004_t000.edf
# Processed: aaaaamuy_s004_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamuy_s008_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 305999  =      0.000 ...  1223.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamuy_s008_t000.edf
# Processed: aaaaamuy_s008_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaamuy_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 304749  =      0.000 ...  1218.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaamuy_s011_t000.edf
# Processed: aaaaamuy_s011_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanag_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 303499  =      0.000 ...  1213.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanag_s001_t001.edf
# Processed: aaaaanag_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanag_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 311499  =      0.000 ...  1245.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanag_s002_t000.edf
# Processed: aaaaanag_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaandx_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 333249  =      0.000 ...  1332.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaandx_s001_t001.edf
# Processed: aaaaandx_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanfk_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 310999  =      0.000 ...  1243.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanfk_s001_t000.edf
# Processed: aaaaanfk_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanfk_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 345999  =      0.000 ...  1383.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanfk_s002_t000.edf
# Processed: aaaaanfk_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanfl_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 318999  =      0.000 ...  1275.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanfl_s001_t000.edf
# Processed: aaaaanfl_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanhr_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 318749  =      0.000 ...  1274.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanhr_s001_t000.edf
# Processed: aaaaanhr_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanjh_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 311551  =      0.000 ...  1216.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanjh_s001_t000.edf
# Processed: aaaaanjh_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanjh_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 343249  =      0.000 ...  1372.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanjh_s003_t000.edf
# Processed: aaaaanjh_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaankz_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300749  =      0.000 ...  1202.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaankz_s001_t000.edf
# Processed: aaaaankz_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaankz_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 304999  =      0.000 ...  1219.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaankz_s002_t000.edf
# Processed: aaaaankz_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaankz_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300249  =      0.000 ...  1200.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaankz_s004_t000.edf
# Processed: aaaaankz_s004_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaankz_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 304249  =      0.000 ...  1216.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaankz_s005_t000.edf
# Processed: aaaaankz_s005_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanmf_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 356249  =      0.000 ...  1424.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanmf_s001_t000.edf
# Processed: aaaaanmf_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaannz_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 331775  =      0.000 ...  1295.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaannz_s004_t001.edf
# Processed: aaaaannz_s004_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaannz_s008_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 354499  =      0.000 ...  1417.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaannz_s008_t001.edf
# Processed: aaaaannz_s008_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanog_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 357999  =      0.000 ...  1431.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanog_s001_t000.edf
# Processed: aaaaanog_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanog_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 300749  =      0.000 ...  1202.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanog_s002_t000.edf
# Processed: aaaaanog_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanog_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 301249  =      0.000 ...  1204.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanog_s005_t000.edf
# Processed: aaaaanog_s005_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanog_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 348249  =      0.000 ...  1392.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanog_s006_t000.edf
# Processed: aaaaanog_s006_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanog_s008_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 340223  =      0.000 ...  1328.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanog_s008_t000.edf
# Processed: aaaaanog_s008_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanog_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 331499  =      0.000 ...  1325.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanog_s010_t000.edf
# Processed: aaaaanog_s010_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanwn_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 320767  =      0.000 ...  1252.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanwn_s003_t001.edf
# Processed: aaaaanwn_s003_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaanzp_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 318749  =      0.000 ...  1274.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaanzp_s001_t000.edf
# Processed: aaaaanzp_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaock_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 330999  =      0.000 ...  1323.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaock_s001_t000.edf
# Processed: aaaaaock_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaock_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1393999  =      0.000 ...  1393.999 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaock_s002_t000.edf
# Processed: aaaaaock_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaocl_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 330749  =      0.000 ...  1322.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaocl_s001_t000.edf
# Processed: aaaaaocl_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaogc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 336249  =      0.000 ...  1344.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaogc_s001_t000.edf
# Processed: aaaaaogc_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaogc_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 320249  =      0.000 ...  1280.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaogc_s003_t000.edf
# Processed: aaaaaogc_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaooo_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1385999  =      0.000 ...  1385.999 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaooo_s005_t000.edf
# Processed: aaaaaooo_s005_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaoou_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 331249  =      0.000 ...  1324.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaoou_s001_t000.edf
# Processed: aaaaaoou_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaotl_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 375499  =      0.000 ...  1501.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaotl_s001_t000.edf
# Processed: aaaaaotl_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaoui_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 344499  =      0.000 ...  1377.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaoui_s002_t001.edf
# Processed: aaaaaoui_s002_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaovm_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 329983  =      0.000 ...  1288.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaovm_s001_t001.edf
# Processed: aaaaaovm_s001_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaovm_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 317695  =      0.000 ...  1240.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaovm_s002_t004.edf
# Processed: aaaaaovm_s002_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaovm_s004_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 319231  =      0.000 ...  1246.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaovm_s004_t008.edf
# Processed: aaaaaovm_s004_t008.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaowq_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 313249  =      0.000 ...  1252.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaowq_s001_t000.edf
# Processed: aaaaaowq_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaozy_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 375749  =      0.000 ...  1502.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaozy_s001_t000.edf
# Processed: aaaaaozy_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapfa_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 326655  =      0.000 ...  1275.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapfa_s001_t000.edf
# Processed: aaaaapfa_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapfa_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 315249  =      0.000 ...  1260.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapfa_s004_t000.edf
# Processed: aaaaapfa_s004_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapge_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 368999  =      0.000 ...  1475.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapge_s001_t000.edf
# Processed: aaaaapge_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaaphz_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 316749  =      0.000 ...  1266.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaaphz_s001_t000.edf
# Processed: aaaaaphz_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapjn_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 342499  =      0.000 ...  1369.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapjn_s001_t000.edf
# Processed: aaaaapjn_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapkm_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 326749  =      0.000 ...  1306.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapkm_s002_t001.edf
# Processed: aaaaapkm_s002_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapri_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 322749  =      0.000 ...  1290.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapri_s001_t000.edf
# Processed: aaaaapri_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapvx_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 349999  =      0.000 ...  1399.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapvx_s001_t000.edf
# Processed: aaaaapvx_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\process_epilepsy_20to24_2\aaaaapwd_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 314749  =      0.000 ...  1258.996 secs...
# Processed file: process_epilepsy_20to24_2\aaaaapwd_s001_t001.edf
# Processed: aaaaapwd_s001_t001.edf

# %%
def process_single_edf(file, df, max_length):
    raw = mne.io.read_raw_edf(file, preload=True)
    
    # Select even-numbered channels (2nd, 4th, 6th, etc.)
    even_channels = raw.get_data()[1::2, :]  # Take even-numbered channels (0-based index)
    
    # Compute average signal
    avg_signal = np.mean(even_channels, axis=0)
    
    # Update max_length if this file has more time points
    if avg_signal.shape[0] > max_length:
        max_length = avg_signal.shape[0]
    
    # Pad shorter rows with 0 and ensure consistency across all rows
    row_data = np.pad(avg_signal, (0, max_length - avg_signal.shape[0]), 'constant', constant_values=0)  # Pad shorter rows with 0
    df_row = pd.DataFrame([row_data], columns=[f"Time_{i}" for i in range(max_length)])
    df_row['Label'] = 'no_epilepsy'  # Add label column
    
    # Align existing data to new max_length by adding columns with 0 to shorter rows
    if df.shape[1] < max_length + 1:  # +1 for the Label column
        extra_columns = max_length - (df.shape[1] - 1)  # Subtract 1 for the Label column
        for i in range(df.shape[0]):
            df.loc[i, [f"Time_{j}" for j in range(df.shape[1] - 1, max_length)]] = 0  # Fill with 0
    
    # Concatenate the new row to the DataFrame
    df = pd.concat([df, df_row], ignore_index=True)
    
    return df, max_length


# Main function to process all EDF files in a directory
def process_all_edf_files(path, output_csv):
    df = pd.DataFrame()  # Initialize empty DataFrame to store all data
    max_length = 0  # To keep track of the maximum number of time points
    
    # Loop through all EDF files in the directory
    for filename in os.listdir(path):
        if filename.endswith('.edf'):
            input_file = os.path.join(path, filename)
            
            # Process the file and update the DataFrame
            df, max_length = process_single_edf(input_file, df, max_length)
            print(f"Processed: {filename}")
    
    # Save the final DataFrame to a CSV file
    df.to_csv(output_csv, index=False)
    print(f"Data has been saved to {output_csv}")

# %%
import numpy as np
import mne
import pandas as pd
import os

def process_single_edf(file, max_length, output_csv):
    raw = mne.io.read_raw_edf(file, preload=True)
    
    # Select even-numbered channels (2nd, 4th, 6th, etc.)
    even_channels = raw.get_data()[1::2, :]  # Take even-numbered channels (0-based index)
    
    # Compute average signal
    avg_signal = np.mean(even_channels, axis=0)
    
    # Update max_length if this file has more time points
    if avg_signal.shape[0] > max_length:
        max_length = avg_signal.shape[0]
    
    # Pad shorter rows with 0 and ensure consistency across all rows
    row_data = np.pad(avg_signal, (0, max_length - avg_signal.shape[0]), 'constant', constant_values=0)  # Pad shorter rows with 0
    df_row = pd.DataFrame([row_data], columns=[f"Time_{i}" for i in range(max_length)])
    df_row['Label'] = 'epilepsy'  # Add label column
    
    # Save to CSV file (append) without duplicating existing data
    df_row.to_csv(output_csv, mode='a', header=not os.path.exists(output_csv), index=False)
    
    return max_length

# Main function to process all EDF files in a directory
def process_all_edf_files(path, output_csv):
    max_length = 0  # To keep track of the maximum number of time points
    
    # Loop through all EDF files in the directory
    for filename in os.listdir(path):
        if filename.endswith('.edf'):
            input_file = os.path.join(path, filename)
            
            # Process the file and update the DataFrame
            max_length = process_single_edf(input_file, max_length, output_csv)
            print(f"Processed: {filename}")
    
    print(f"Data has been saved to {output_csv}")

# %%
# path = "process_noepilepsy_20to24"
path = "yes_under_1m"
output_csv = "yes_even.csv"


process_all_edf_files(path, output_csv)
# Out:
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3327  =      0.000 ...    12.996 secs...
# Processed: aaaaaanr_s017_t012.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t030.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6655  =      0.000 ...    25.996 secs...
# Processed: aaaaaanr_s017_t030.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processed: aaaaaanr_s017_t031.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4351  =      0.000 ...    16.996 secs...
# Processed: aaaaaanr_s017_t033.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processed: aaaaaanr_s018_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10751  =      0.000 ...    41.996 secs...
# Processed: aaaaaanr_s018_t014.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processed: aaaaaanr_s018_t024.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6399  =      0.000 ...    24.996 secs...
# Processed: aaaaaanr_s018_t025.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7167  =      0.000 ...    27.996 secs...
# Processed: aaaaaanr_s018_t026.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t027.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7935  =      0.000 ...    30.996 secs...
# Processed: aaaaaanr_s018_t027.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processed: aaaaaanr_s019_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3071  =      0.000 ...    11.996 secs...
# Processed: aaaaaanr_s019_t005.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processed: aaaaaanr_s019_t006.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s020_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5887  =      0.000 ...    22.996 secs...
# Processed: aaaaaanr_s020_t026.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s021_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6655  =      0.000 ...    25.996 secs...
# Processed: aaaaaanr_s021_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s021_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processed: aaaaaanr_s021_t008.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5249  =      0.000 ...    20.996 secs...
# Processed: aaaaabdn_s005_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Processed: aaaaabdn_s005_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5249  =      0.000 ...    20.996 secs...
# Processed: aaaaabdn_s005_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14499  =      0.000 ...    57.996 secs...
# Processed: aaaaabdn_s005_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4249  =      0.000 ...    16.996 secs...
# Processed: aaaaabdn_s005_t006.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processed: aaaaabdn_s007_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processed: aaaaabdn_s009_t007.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processed: aaaaabdn_s009_t008.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processed: aaaaabdn_s009_t011.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processed: aaaaabdn_s010_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processed: aaaaabdn_s010_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14591  =      0.000 ...    56.996 secs...
# Processed: aaaaabdn_s010_t009.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s001_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processed: aaaaabhz_s001_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s024_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13823  =      0.000 ...    26.998 secs...
# Processed: aaaaabhz_s024_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s026_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15359  =      0.000 ...    29.998 secs...
# Processed: aaaaabhz_s026_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1023  =      0.000 ...     1.998 secs...
# Processed: aaaaabhz_s027_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     2.998 secs...
# Processed: aaaaabhz_s027_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5631  =      0.000 ...    10.998 secs...
# Processed: aaaaabhz_s027_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4095  =      0.000 ...     7.998 secs...
# Processed: aaaaabhz_s027_t005.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     4.998 secs...
# Processed: aaaaabhz_s027_t006.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5631  =      0.000 ...    10.998 secs...
# Processed: aaaaabhz_s027_t013.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4607  =      0.000 ...     8.998 secs...
# Processed: aaaaabhz_s027_t014.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s030_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4863  =      0.000 ...    18.996 secs...
# Processed: aaaaabhz_s030_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s033_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processed: aaaaabhz_s033_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3749  =      0.000 ...    14.996 secs...
# Processed: aaaaaifn_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1279  =      0.000 ...     4.996 secs...
# Processed: aaaaaifn_s005_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4249  =      0.000 ...    16.996 secs...
# Processed: aaaaaifn_s007_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifp_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1499  =      0.000 ...     5.996 secs...
# Processed: aaaaaifp_s003_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifp_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Processed: aaaaaifp_s003_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaint_s004_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 17999  =      0.000 ...    44.998 secs...
# Processed: aaaaaint_s004_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajat_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 22399  =      0.000 ...    55.998 secs...
# Processed: aaaaajat_s006_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Processed: aaaaajqo_s007_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s020_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4999  =      0.000 ...    19.996 secs...
# Processed: aaaaajqo_s020_t006.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s025_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Processed: aaaaajqo_s025_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s032_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5499  =      0.000 ...    21.996 secs...
# Processed: aaaaajqo_s032_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajud_s013_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processed: aaaaajud_s013_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaakfe_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8191  =      0.000 ...    31.996 secs...
# Processed: aaaaakfe_s002_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaakyc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11749  =      0.000 ...    46.996 secs...
# Processed: aaaaakyc_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalfg_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15103  =      0.000 ...    58.996 secs...
# Processed: aaaaalfg_s003_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8191  =      0.000 ...    31.996 secs...
# Processed: aaaaalib_s003_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6911  =      0.000 ...    26.996 secs...
# Processed: aaaaalib_s005_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processed: aaaaalib_s005_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3071  =      0.000 ...    11.996 secs...
# Processed: aaaaalib_s007_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalim_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4095  =      0.000 ...    15.996 secs...
# Processed: aaaaalim_s004_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4863  =      0.000 ...    18.996 secs...
# Processed: aaaaalzg_s011_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processed: aaaaalzg_s011_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7167  =      0.000 ...    27.996 secs...
# Processed: aaaaalzg_s011_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10239  =      0.000 ...    39.996 secs...
# Processed: aaaaalzg_s011_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamde_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2999  =      0.000 ...    11.996 secs...
# Processed: aaaaamde_s005_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamgc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1249  =      0.000 ...     4.996 secs...
# Processed: aaaaamgc_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 27135  =      0.000 ...    52.998 secs...
# Processed: aaaaamnj_s006_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processed: aaaaamnj_s009_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t006.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t007.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t008.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t011.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t012.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t013.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t014.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t015.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t016.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t017.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t018.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t019.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t023.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s009_t024.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t005.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t007.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t008.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t009.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t011.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t012.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t016.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t018.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s010_t020.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s011_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 511  =      0.000 ...     1.996 secs...
# Processed: aaaaamnj_s011_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s011_t006.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s011_t008.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s011_t009.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s011_t010.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s011_t013.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s012_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s012_t009.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s012_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s012_t010.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s013_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s013_t005.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processed: aaaaamnj_s013_t009.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s003_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6911  =      0.000 ...    26.996 secs...
# Processed: aaaaamoa_s003_t008.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1279  =      0.000 ...     4.996 secs...
# Processed: aaaaamoa_s006_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s006_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processed: aaaaamoa_s006_t005.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamsw_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6249  =      0.000 ...    24.996 secs...
# Processed: aaaaamsw_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamuy_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5999  =      0.000 ...    23.996 secs...
# Processed: aaaaamuy_s007_t004.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaannz_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10751  =      0.000 ...    41.996 secs...
# Processed: aaaaannz_s005_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaannz_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Processed: aaaaannz_s009_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaocl_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5119  =      0.000 ...     9.998 secs...
# Processed: aaaaaocl_s003_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaoom_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processed: aaaaaoom_s003_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaooo_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3071  =      0.000 ...    11.996 secs...
# Processed: aaaaaooo_s004_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7679  =      0.000 ...    29.996 secs...
# Processed: aaaaaovm_s001_t000.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processed: aaaaaovm_s003_t002.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processed: aaaaaovm_s003_t003.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processed: aaaaaovm_s003_t007.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processed: aaaaaovm_s003_t009.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaowq_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processed: aaaaaowq_s007_t001.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapfa_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11519  =      0.000 ...    44.996 secs...
# Processed: aaaaapfa_s002_t005.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapfa_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14079  =      0.000 ...    54.996 secs...
# Processed: aaaaapfa_s002_t006.edf
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapkm_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processed: aaaaapkm_s006_t001.edf
# Data has been saved to yes_even.csv

# %%
import numpy as np
import mne
import pandas as pd
import os

# Function to get the duration of each EDF file
def get_edf_duration(file):
    raw = mne.io.read_raw_edf(file, preload=False)  # Preload=False for faster duration check
    duration = raw.times[-1]  # The last time point gives the duration in seconds
    return duration

# Function to process a single EDF file and append it to the CSV
def process_single_edf(file, max_length, output_csv):
    raw = mne.io.read_raw_edf(file, preload=True)
    
    # Select even-numbered channels (2nd, 4th, 6th, etc.)
    even_channels = raw.get_data()[0::2, :]  # Take even-numbered channels (0-based index)
    
    # Compute average signal
    avg_signal = np.mean(even_channels, axis=0)
    
    # Update max_length if this file has more time points
    if avg_signal.shape[0] > max_length:
        max_length = avg_signal.shape[0]
    
    # Pad shorter rows with 0 and ensure consistency across all rows
    row_data = np.pad(avg_signal, (0, max_length - avg_signal.shape[0]), 'constant', constant_values=0)  # Pad shorter rows with 0
    df_row = pd.DataFrame([row_data], columns=[f"Time_{i}" for i in range(max_length)])
    df_row['Label'] = 'epilepsy'  # Add label column
    
    # Save to CSV file (append) without duplicating existing data
    df_row.to_csv(output_csv, mode='a', header=not os.path.exists(output_csv), index=False)
    
    return max_length

# Main function to process all EDF files in a directory, with longest duration first
def process_all_edf_files(path, output_csv):
    # First, scan all EDF files to find their durations
    edf_files = []
    for filename in os.listdir(path):
        if filename.endswith('.edf'):
            input_file = os.path.join(path, filename)
            duration = get_edf_duration(input_file)  # Get the duration of the EDF file
            edf_files.append((input_file, duration))
    
    # Sort files by duration (descending, longest first)
    edf_files.sort(key=lambda x: x[1], reverse=True)
    
    # Initialize variables
    max_length = 0  # To keep track of the maximum number of time points
    
    # Process each file (starting with the longest one)
    for input_file, duration in edf_files:
        print(f"Processing: {os.path.basename(input_file)} with duration {duration:.2f} seconds")
        
        # Process the file and update the DataFrame
        max_length = process_single_edf(input_file, max_length, output_csv)
    
    print(f"Data has been saved to {output_csv}")

# %%
import numpy as np
import mne
import pandas as pd
import os

# Function to get the duration of each EDF file
def get_edf_duration_2(file):
    raw = mne.io.read_raw_edf(file, preload=False)  # Preload=False for faster duration check
    duration = raw.times[-1]  # The last time point gives the duration in seconds
    return duration

# Function to process a single EDF file and append it to the CSV
def process_single_edf_2(file, max_length, output_csv):
    raw = mne.io.read_raw_edf(file, preload=True)
    
    # Select even-numbered channels (2nd, 4th, 6th, etc.)
    even_channels = raw.get_data()[1::2, :]  # Take even-numbered channels (0-based index)
    
    # Compute average signal
    avg_signal = np.mean(even_channels, axis=0)
    
    # Update max_length if this file has more time points
    if avg_signal.shape[0] > max_length:
        max_length = avg_signal.shape[0]
    
    # Pad shorter rows with 0 and ensure consistency across all rows
    row_data = np.pad(avg_signal, (0, max_length - avg_signal.shape[0]), 'constant', constant_values=0)  # Pad shorter rows with 0
    df_row = pd.DataFrame([row_data], columns=[f"Time_{i}" for i in range(max_length)])
    df_row['Label'] = 'epilepsy'  # Add label column
    
    # Save to CSV file (append) without duplicating existing data
    df_row.to_csv(output_csv, mode='a', header=not os.path.exists(output_csv), index=False)
    
    return max_length

# Main function to process all EDF files in a directory, with longest duration first
def process_all_edf_files_2(path, output_csv):
    # First, scan all EDF files to find their durations
    edf_files = []
    for filename in os.listdir(path):
        if filename.endswith('.edf'):
            input_file = os.path.join(path, filename)
            duration = get_edf_duration_2(input_file)  # Get the duration of the EDF file
            edf_files.append((input_file, duration))
    
    # Sort files by duration (descending, longest first)
    edf_files.sort(key=lambda x: x[1], reverse=True)
    
    # Initialize variables
    max_length = 0  # To keep track of the maximum number of time points
    
    # Process each file (starting with the longest one)
    for input_file, duration in edf_files:
        print(f"Processing: {os.path.basename(input_file)} with duration {duration:.2f} seconds")
        
        # Process the file and update the DataFrame
        max_length = process_single_edf_2(input_file, max_length, output_csv)
    
    print(f"Data has been saved to {output_csv}")

# %%
path = "yes_under_1m"
# path = "process_noepilepsy_10to13"
# path = "under_1m"
output_csv = "epilepsy_odd.csv" 
process_all_edf_files(path, output_csv)

output_csv2 = "epilepsy_even.csv" 
process_all_edf_files_2(path, output_csv2)
# Out:
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t030.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t027.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s020_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s021_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s021_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s001_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s024_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s026_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s030_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s033_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifp_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifp_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaint_s004_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajat_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s020_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s025_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s032_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajud_s013_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaakfe_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaakyc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalfg_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalim_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamde_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamgc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s012_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s012_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s003_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s006_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamsw_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamuy_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaannz_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaannz_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaocl_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaoom_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaooo_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaowq_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapfa_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapfa_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapkm_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Processing: aaaaalfg_s003_t003.edf with duration 59.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalfg_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15103  =      0.000 ...    58.996 secs...
# Processing: aaaaabdn_s005_t004.edf with duration 58.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14499  =      0.000 ...    57.996 secs...
# Processing: aaaaabdn_s010_t009.edf with duration 57.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14591  =      0.000 ...    56.996 secs...
# Processing: aaaaajat_s006_t002.edf with duration 56.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajat_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 22399  =      0.000 ...    55.998 secs...
# Processing: aaaaapfa_s002_t006.edf with duration 55.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapfa_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14079  =      0.000 ...    54.996 secs...
# Processing: aaaaamnj_s006_t000.edf with duration 53.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 27135  =      0.000 ...    52.998 secs...
# Processing: aaaaakyc_s001_t000.edf with duration 47.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaakyc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11749  =      0.000 ...    46.996 secs...
# Processing: aaaaaint_s004_t004.edf with duration 45.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaint_s004_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 17999  =      0.000 ...    44.998 secs...
# Processing: aaaaapfa_s002_t005.edf with duration 45.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapfa_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11519  =      0.000 ...    44.996 secs...
# Processing: aaaaajqo_s025_t000.edf with duration 44.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s025_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Processing: aaaaaanr_s018_t014.edf with duration 42.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10751  =      0.000 ...    41.996 secs...
# Processing: aaaaannz_s005_t002.edf with duration 42.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaannz_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10751  =      0.000 ...    41.996 secs...
# Processing: aaaaalzg_s011_t003.edf with duration 40.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10239  =      0.000 ...    39.996 secs...
# Processing: aaaaakfe_s002_t000.edf with duration 32.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaakfe_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8191  =      0.000 ...    31.996 secs...
# Processing: aaaaalib_s003_t000.edf with duration 32.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8191  =      0.000 ...    31.996 secs...
# Processing: aaaaaanr_s018_t027.edf with duration 31.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t027.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7935  =      0.000 ...    30.996 secs...
# Processing: aaaaabhz_s026_t001.edf with duration 30.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s026_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15359  =      0.000 ...    29.998 secs...
# Processing: aaaaaovm_s001_t000.edf with duration 30.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7679  =      0.000 ...    29.996 secs...
# Processing: aaaaaanr_s018_t026.edf with duration 28.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7167  =      0.000 ...    27.996 secs...
# Processing: aaaaalzg_s011_t002.edf with duration 28.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7167  =      0.000 ...    27.996 secs...
# Processing: aaaaabhz_s024_t002.edf with duration 27.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s024_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13823  =      0.000 ...    26.998 secs...
# Processing: aaaaalib_s005_t001.edf with duration 27.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6911  =      0.000 ...    26.996 secs...
# Processing: aaaaamoa_s003_t008.edf with duration 27.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s003_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6911  =      0.000 ...    26.996 secs...
# Processing: aaaaaanr_s017_t030.edf with duration 26.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t030.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6655  =      0.000 ...    25.996 secs...
# Processing: aaaaaanr_s021_t000.edf with duration 26.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s021_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6655  =      0.000 ...    25.996 secs...
# Processing: aaaaaanr_s018_t025.edf with duration 25.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6399  =      0.000 ...    24.996 secs...
# Processing: aaaaamsw_s001_t000.edf with duration 25.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamsw_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6249  =      0.000 ...    24.996 secs...
# Processing: aaaaamuy_s007_t004.edf with duration 24.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamuy_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5999  =      0.000 ...    23.996 secs...
# Processing: aaaaaanr_s020_t026.edf with duration 23.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s020_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5887  =      0.000 ...    22.996 secs...
# Processing: aaaaannz_s009_t000.edf with duration 23.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaannz_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Processing: aaaaajqo_s032_t000.edf with duration 22.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s032_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5499  =      0.000 ...    21.996 secs...
# Processing: aaaaabdn_s005_t001.edf with duration 21.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5249  =      0.000 ...    20.996 secs...
# Processing: aaaaabdn_s005_t003.edf with duration 21.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5249  =      0.000 ...    20.996 secs...
# Processing: aaaaajqo_s020_t006.edf with duration 20.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s020_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4999  =      0.000 ...    19.996 secs...
# Processing: aaaaabhz_s030_t000.edf with duration 19.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s030_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4863  =      0.000 ...    18.996 secs...
# Processing: aaaaalzg_s011_t000.edf with duration 19.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4863  =      0.000 ...    18.996 secs...
# Processing: aaaaajqo_s007_t000.edf with duration 19.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajqo_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Processing: aaaaaanr_s017_t033.edf with duration 17.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4351  =      0.000 ...    16.996 secs...
# Processing: aaaaabdn_s005_t006.edf with duration 17.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4249  =      0.000 ...    16.996 secs...
# Processing: aaaaaifn_s007_t000.edf with duration 17.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4249  =      0.000 ...    16.996 secs...
# Processing: aaaaalim_s004_t001.edf with duration 16.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalim_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4095  =      0.000 ...    15.996 secs...
# Processing: aaaaaifn_s003_t000.edf with duration 15.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3749  =      0.000 ...    14.996 secs...
# Processing: aaaaabhz_s001_t002.edf with duration 14.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s001_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processing: aaaaaanr_s017_t012.edf with duration 13.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3327  =      0.000 ...    12.996 secs...
# Processing: aaaaabdn_s005_t002.edf with duration 13.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Processing: aaaaaifp_s003_t002.edf with duration 13.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifp_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Processing: aaaaaanr_s019_t005.edf with duration 12.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3071  =      0.000 ...    11.996 secs...
# Processing: aaaaalib_s007_t000.edf with duration 12.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3071  =      0.000 ...    11.996 secs...
# Processing: aaaaaooo_s004_t001.edf with duration 12.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaooo_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3071  =      0.000 ...    11.996 secs...
# Processing: aaaaamde_s005_t000.edf with duration 12.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamde_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2999  =      0.000 ...    11.996 secs...
# Processing: aaaaabhz_s027_t004.edf with duration 11.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5631  =      0.000 ...    10.998 secs...
# Processing: aaaaabhz_s027_t013.edf with duration 11.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5631  =      0.000 ...    10.998 secs...
# Processing: aaaaaanr_s019_t003.edf with duration 11.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processing: aaaaalzg_s011_t001.edf with duration 11.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalzg_s011_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processing: aaaaaocl_s003_t001.edf with duration 10.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaocl_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5119  =      0.000 ...     9.998 secs...
# Processing: aaaaaanr_s019_t006.edf with duration 10.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s019_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processing: aaaaabdn_s007_t000.edf with duration 10.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processing: aaaaajud_s013_t000.edf with duration 10.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaajud_s013_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processing: aaaaalib_s005_t002.edf with duration 10.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaalib_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processing: aaaaaoom_s003_t001.edf with duration 10.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaoom_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     9.996 secs...
# Processing: aaaaabhz_s027_t014.edf with duration 9.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4607  =      0.000 ...     8.998 secs...
# Processing: aaaaaanr_s018_t003.edf with duration 9.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processing: aaaaaanr_s018_t024.edf with duration 9.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s018_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processing: aaaaaovm_s003_t002.edf with duration 9.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processing: aaaaaovm_s003_t003.edf with duration 9.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processing: aaaaaovm_s003_t007.edf with duration 9.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processing: aaaaabhz_s027_t005.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4095  =      0.000 ...     7.998 secs...
# Processing: aaaaaanr_s017_t031.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s017_t031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaabdn_s009_t007.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaabhz_s033_t000.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s033_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaamoa_s006_t005.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s006_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaaovm_s003_t009.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaaowq_s007_t001.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaowq_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaaanr_s021_t008.edf with duration 7.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s021_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processing: aaaaabdn_s010_t000.edf with duration 7.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processing: aaaaabdn_s010_t001.edf with duration 7.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processing: aaaaabdn_s009_t008.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaabdn_s009_t011.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaamnj_s009_t000.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaapkm_s006_t001.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapkm_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaaifp_s003_t001.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifp_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1499  =      0.000 ...     5.996 secs...
# Processing: aaaaabhz_s027_t006.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     4.998 secs...
# Processing: aaaaaifn_s005_t004.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1279  =      0.000 ...     4.996 secs...
# Processing: aaaaamoa_s006_t001.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1279  =      0.000 ...     4.996 secs...
# Processing: aaaaamgc_s001_t000.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamgc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1249  =      0.000 ...     4.996 secs...
# Processing: aaaaabhz_s027_t003.edf with duration 3.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     2.998 secs...
# Processing: aaaaabhz_s027_t000.edf with duration 2.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1023  =      0.000 ...     1.998 secs...
# Processing: aaaaamnj_s011_t003.edf with duration 2.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 511  =      0.000 ...     1.996 secs...
# Processing: aaaaamnj_s009_t003.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t003.edf...
# EDF file detected
# ...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaovm_s003_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaaowq_s007_t001.edf with duration 8.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaowq_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaaanr_s021_t008.edf with duration 7.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaanr_s021_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processing: aaaaabdn_s010_t000.edf with duration 7.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processing: aaaaabdn_s010_t001.edf with duration 7.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1791  =      0.000 ...     6.996 secs...
# Processing: aaaaabdn_s009_t008.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaabdn_s009_t011.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabdn_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaamnj_s009_t000.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaapkm_s006_t001.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaapkm_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaaifp_s003_t001.edf with duration 6.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifp_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1499  =      0.000 ...     5.996 secs...
# Processing: aaaaabhz_s027_t006.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2559  =      0.000 ...     4.998 secs...
# Processing: aaaaaifn_s005_t004.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaaifn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1279  =      0.000 ...     4.996 secs...
# Processing: aaaaamoa_s006_t001.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamoa_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1279  =      0.000 ...     4.996 secs...
# Processing: aaaaamgc_s001_t000.edf with duration 5.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamgc_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1249  =      0.000 ...     4.996 secs...
# Processing: aaaaabhz_s027_t003.edf with duration 3.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     2.998 secs...
# Processing: aaaaabhz_s027_t000.edf with duration 2.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaabhz_s027_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1023  =      0.000 ...     1.998 secs...
# Processing: aaaaamnj_s011_t003.edf with duration 2.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 511  =      0.000 ...     1.996 secs...
# Processing: aaaaamnj_s009_t003.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t006.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t007.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t008.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t011.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t012.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t013.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t014.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t015.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t016.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t017.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t018.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t019.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t023.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s009_t024.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s009_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t002.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t003.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t004.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t005.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t007.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t008.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t009.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t011.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t012.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t016.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t018.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s010_t020.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s010_t020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s011_t001.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s011_t006.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s011_t008.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s011_t009.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s011_t010.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s011_t013.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s011_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s012_t009.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s012_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s012_t010.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s012_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s013_t004.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s013_t005.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaamnj_s013_t009.edf with duration 1.00 seconds
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\yes_under_1m\aaaaamnj_s013_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Data has been saved to epilepsy_even.csv

# %%
import numpy as np
import mne
import pandas as pd
import os

# Function to get the data from even-numbered channels
def get_even_channel_data(file):
    raw = mne.io.read_raw_edf(file, preload=True)
    even_channels = raw.get_data()[0::2, :]  # Get even-numbered channels (0-based index)
    avg_signal = np.mean(even_channels, axis=0)  # Compute the average signal
    return avg_signal

# First pass: Determine the maximum length across all files
def find_max_length(path):
    max_length = 0
    for filename in os.listdir(path):
        if filename.endswith('.edf'):
            input_file = os.path.join(path, filename)
            avg_signal = get_even_channel_data(input_file)  # Get the average signal
            if avg_signal.shape[0] > max_length:
                max_length = avg_signal.shape[0]  # Update max_length if this file is longer
    return max_length

# Function to process a single EDF file and append it to the CSV
def process_single_edf_2(file, max_length, output_csv, label):
    avg_signal = get_even_channel_data(file)
    
    # Pad shorter signals with 0 and ensure consistency across all rows
    row_data = np.pad(avg_signal, (0, max_length - avg_signal.shape[0]), 'constant', constant_values=0)  # Pad to max_length
    df_row = pd.DataFrame([row_data], columns=[f"Time_{i}" for i in range(max_length)])  # Create a DataFrame
    
    # Add the manually provided label column
    df_row['Label'] = label
    
    # Save to CSV file (append) without duplicating existing data
    df_row.to_csv(output_csv, mode='a', header=not os.path.exists(output_csv), index=False)

# Main function to process all EDF files in a directory, ensuring the same time point length
def process_all_edf_files_2(path, output_csv, label):
    # First, calculate the max length by checking all EDF files
    max_length = find_max_length(path)
    print(f"Maximum time points across all files: {max_length}")
    
    # Process each EDF file
    for filename in os.listdir(path):
        if filename.endswith('.edf'):
            input_file = os.path.join(path, filename)
            print(f"Processing: {os.path.basename(input_file)} with label: {label}")
            
            # Process the file and append data to CSV
            process_single_edf_2(input_file, max_length, output_csv, label)

    print(f"Data has been saved to {output_csv}")

# Example usage:
# You can call this function with either 'epilepsy' or 'no_epilepsy' depending on the files you are processing:
# process_all_edf_files_2('path_to_edf_files', 'output_file.csv', 'epilepsy')
# process_all_edf_files_2('path_to_edf_files', 'output_file.csv', 'no_epilepsy')

# %%
path = "no_under_1m"
process_all_edf_files_2(path, 'ni_odd.csv', 'no_epilepsy')
# Out:
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaebo_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaigj_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaigj_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaalpi_s001_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaalyg_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamhx_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 12749  =      0.000 ...    50.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaammt_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8499  =      0.000 ...    33.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2499  =      0.000 ...     9.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10499  =      0.000 ...    41.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8999  =      0.000 ...    35.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1249  =      0.000 ...     4.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8749  =      0.000 ...    34.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1499  =      0.000 ...     5.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2999  =      0.000 ...    11.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14499  =      0.000 ...    57.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t021.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t022.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11749  =      0.000 ...    46.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11999  =      0.000 ...    47.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3999  =      0.000 ...    15.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t028.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t029.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t034.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10249  =      0.000 ...    40.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t037.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13499  =      0.000 ...    53.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaandb_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaandb_s002_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6999  =      0.000 ...    27.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14249  =      0.000 ...    56.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5499  =      0.000 ...    21.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13249  =      0.000 ...    52.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2999  =      0.000 ...    11.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15103  =      0.000 ...    58.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s008_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s008_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s008_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s010_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s010_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s012_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s012_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s012_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s014_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s014_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s014_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanky_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13999  =      0.000 ...    55.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanky_s001_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11749  =      0.000 ...    46.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaannv_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14749  =      0.000 ...    58.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaannv_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5249  =      0.000 ...    20.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 12249  =      0.000 ...    48.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1999  =      0.000 ...     7.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4249  =      0.000 ...    16.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13499  =      0.000 ...    53.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9249  =      0.000 ...    36.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14249  =      0.000 ...    56.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9749  =      0.000 ...    38.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6499  =      0.000 ...    25.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaokb_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4499  =      0.000 ...    17.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaott_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaott_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8959  =      0.000 ...    34.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoxn_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4999  =      0.000 ...    19.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapfw_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13499  =      0.000 ...    53.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10249  =      0.000 ...    40.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7499  =      0.000 ...    29.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaappj_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4499  =      0.000 ...    17.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaappj_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1249  =      0.000 ...     4.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaappj_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1999  =      0.000 ...     7.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapwy_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapwy_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3839  =      0.000 ...    14.996 secs...
# Maximum time points across all files: 15104
# Processing: aaaaaebo_s002_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaebo_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Processing: aaaaaigj_s004_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaigj_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Processing: aaaaaigj_s005_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaigj_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Processing: aaaaalpi_s001_t003.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaalpi_s001_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processing: aaaaalyg_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaalyg_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Processing: aaaaamhx_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamhx_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 12749  =      0.000 ...    50.996 secs...
# Processing: aaaaammt_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaammt_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8499  =      0.000 ...    33.996 secs...
# Processing: aaaaamum_s002_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Processing: aaaaamum_s002_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2499  =      0.000 ...     9.996 secs...
# Processing: aaaaamum_s002_t006.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Processing: aaaaamum_s002_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processing: aaaaamum_s002_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10499  =      0.000 ...    41.996 secs...
# Processing: aaaaamum_s002_t009.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Processing: aaaaamum_s002_t012.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8999  =      0.000 ...    35.996 secs...
# Processing: aaaaamum_s002_t013.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1249  =      0.000 ...     4.996 secs...
# Processing: aaaaamum_s002_t014.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8749  =      0.000 ...    34.996 secs...
# Processing: aaaaamum_s002_t015.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processing: aaaaamum_s002_t017.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Processing: aaaaamum_s002_t018.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1499  =      0.000 ...     5.996 secs...
# Processing: aaaaamum_s002_t019.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2999  =      0.000 ...    11.996 secs...
# Processing: aaaaamum_s002_t020.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14499  =      0.000 ...    57.996 secs...
# Processing: aaaaamum_s002_t021.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t021.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Processing: aaaaamum_s002_t022.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t022.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11749  =      0.000 ...    46.996 secs...
# Processing: aaaaamum_s002_t023.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11999  =      0.000 ...    47.996 secs...
# Processing: aaaaamum_s002_t024.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Processing: aaaaamum_s002_t025.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processing: aaaaamum_s002_t026.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3999  =      0.000 ...    15.996 secs...
# Processing: aaaaamum_s002_t028.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t028.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Processing: aaaaamum_s002_t029.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t029.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Processing: aaaaamum_s002_t031.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Processing: aaaaamum_s002_t033.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10999  =      0.000 ...    43.996 secs...
# Processing: aaaaamum_s002_t034.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t034.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10249  =      0.000 ...    40.996 secs...
# Processing: aaaaamum_s002_t037.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaamum_s002_t037.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13499  =      0.000 ...    53.996 secs...
# Processing: aaaaandb_s002_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaandb_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Processing: aaaaandb_s002_t003.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaandb_s002_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6999  =      0.000 ...    27.996 secs...
# Processing: aaaaangg_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14249  =      0.000 ...    56.996 secs...
# Processing: aaaaangg_s002_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Processing: aaaaangg_s002_t004.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5499  =      0.000 ...    21.996 secs...
# Processing: aaaaangg_s002_t009.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Processing: aaaaangg_s002_t010.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13249  =      0.000 ...    52.996 secs...
# Processing: aaaaangg_s002_t011.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6749  =      0.000 ...    26.996 secs...
# Processing: aaaaangg_s002_t014.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaangg_s002_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2999  =      0.000 ...    11.996 secs...
# Processing: aaaaanig_s005_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15103  =      0.000 ...    58.996 secs...
# Processing: aaaaanig_s005_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s005_t006.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaanig_s005_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s005_t009.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s005_t011.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s005_t012.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s005_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s006_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s006_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s006_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s006_t012.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s006_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s007_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s007_t003.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s007_t004.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s007_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s007_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s007_t010.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s007_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s008_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s008_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s008_t006.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s008_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s008_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s008_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s009_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processing: aaaaanig_s009_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processing: aaaaanig_s009_t003.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processing: aaaaanig_s009_t004.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processing: aaaaanig_s009_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2815  =      0.000 ...    10.996 secs...
# Processing: aaaaanig_s009_t010.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s009_t013.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s009_t014.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s009_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s010_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s010_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s010_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s010_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s011_t003.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s011_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s011_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s011_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s011_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s012_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s012_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s012_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s012_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s012_t010.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s012_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s013_t006.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s013_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s013_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s013_t012.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s013_t013.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s013_t014.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s013_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s014_t003.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s014_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s014_t006.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s014_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanig_s014_t011.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanig_s014_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 255  =      0.000 ...     0.996 secs...
# Processing: aaaaanky_s001_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanky_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13999  =      0.000 ...    55.996 secs...
# Processing: aaaaanky_s001_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaanky_s001_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11749  =      0.000 ...    46.996 secs...
# Processing: aaaaannv_s002_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaannv_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14749  =      0.000 ...    58.996 secs...
# Processing: aaaaannv_s002_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaannv_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processing: aaaaaoie_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5249  =      0.000 ...    20.996 secs...
# Processing: aaaaaoie_s002_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 12249  =      0.000 ...    48.996 secs...
# Processing: aaaaaoie_s002_t004.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1999  =      0.000 ...     7.996 secs...
# Processing: aaaaaoie_s002_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4249  =      0.000 ...    16.996 secs...
# Processing: aaaaaoie_s002_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13499  =      0.000 ...    53.996 secs...
# Processing: aaaaaoie_s002_t008.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9249  =      0.000 ...    36.996 secs...
# Processing: aaaaaoie_s002_t010.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 14249  =      0.000 ...    56.996 secs...
# Processing: aaaaaoie_s002_t012.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2749  =      0.000 ...    10.996 secs...
# Processing: aaaaaoie_s002_t013.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9749  =      0.000 ...    38.996 secs...
# Processing: aaaaaoie_s002_t016.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 6499  =      0.000 ...    25.996 secs...
# Processing: aaaaaoie_s002_t018.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoie_s002_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Processing: aaaaaokb_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaokb_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4499  =      0.000 ...    17.996 secs...
# Processing: aaaaaott_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaott_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3499  =      0.000 ...    13.996 secs...
# Processing: aaaaaott_s002_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaott_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8959  =      0.000 ...    34.996 secs...
# Processing: aaaaaoxn_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaaoxn_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4999  =      0.000 ...    19.996 secs...
# Processing: aaaaapfw_s003_t003.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapfw_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2047  =      0.000 ...     7.996 secs...
# Processing: aaaaapkw_s001_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2249  =      0.000 ...     8.996 secs...
# Processing: aaaaapkw_s001_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Processing: aaaaapkw_s002_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaapkw_s002_t004.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapkw_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1535  =      0.000 ...     5.996 secs...
# Processing: aaaaapmu_s002_t002.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13499  =      0.000 ...    53.996 secs...
# Processing: aaaaapmu_s002_t004.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    12.996 secs...
# Processing: aaaaapmu_s002_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4749  =      0.000 ...    18.996 secs...
# Processing: aaaaapmu_s002_t007.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10249  =      0.000 ...    40.996 secs...
# Processing: aaaaapmu_s002_t009.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 7499  =      0.000 ...    29.996 secs...
# Processing: aaaaapmu_s002_t012.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapmu_s002_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5749  =      0.000 ...    22.996 secs...
# Processing: aaaaappj_s001_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaappj_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4499  =      0.000 ...    17.996 secs...
# Processing: aaaaappj_s002_t005.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaappj_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1249  =      0.000 ...     4.996 secs...
# Processing: aaaaappj_s002_t006.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaappj_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1999  =      0.000 ...     7.996 secs...
# Processing: aaaaapwy_s002_t001.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapwy_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2303  =      0.000 ...     8.996 secs...
# Processing: aaaaapwy_s006_t000.edf with label: no_epilepsy
# Extracting EDF parameters from d:\FGW\EDF\v2.0.1_new\no_under_1m\aaaaapwy_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3839  =      0.000 ...    14.996 secs...
# Data has been saved to ni_odd.csv
