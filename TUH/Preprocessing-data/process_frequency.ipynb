# %%
import os
import mne

def count_files_by_sampling_frequency(edf_dir):
    count_250hz = 0
    count_120hz = 0

    for file in os.listdir(edf_dir):
        if file.endswith('.edf'):
            raw_data = mne.io.read_raw_edf(os.path.join(edf_dir, file))
            sfreq = raw_data.info['sfreq']

            if sfreq == 250:
                count_250hz += 1
            elif sfreq == 120:
                count_120hz += 1

    return count_250hz, count_120hz

# Example usage with output printing
edf_directory = 'D:/FGW/EDF/v2.0.1_new/epilepsy/'
count_250hz, count_120hz = count_files_by_sampling_frequency(edf_directory)

print(f"Number of EDF files with 250 Hz sampling frequency: {count_250hz}")
print(f"Number of EDF files with 120 Hz sampling frequency: {count_120hz}")
# Out:
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s005_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s007_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s008_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s010_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s012_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s013_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s014_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s014_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s014_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s015_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s016_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s017_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s017_t030.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s017_t031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s017_t033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t021.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s018_t027.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s019_t020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s020_t026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s021_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s022_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s022_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaanr_s022_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaawu_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaawu_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaawu_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaawu_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaawu_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s005_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s006_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s007_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s008_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s009_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabdn_s010_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s001_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s008_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s009_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s010_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s010_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s010_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s010_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s010_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s011_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s012_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s012_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s012_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s012_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s012_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s012_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s015_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s017_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s018_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s019_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s019_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s019_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s020_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s022_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s024_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s024_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s024_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s025_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s026_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s026_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s026_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s027_t017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s028_t010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s029_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s029_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s029_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s029_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s030_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s030_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s030_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s031_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s031_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s031_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s031_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s032_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s032_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s032_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s032_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s032_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s033_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s033_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s033_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s033_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaabhz_s033_t004.edf...
# EDF file detected
# ...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s005_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s005_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s005_t009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaovm_s007_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s002_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s004_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s004_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s004_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s004_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s006_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s006_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s006_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaowq_s007_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaozy_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s002_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s002_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s002_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s002_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s002_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s002_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapfa_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapge_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaaphz_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapjn_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s003_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s004_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s005_t008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s006_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s006_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s007_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s007_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s007_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s007_t003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapkm_s007_t004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapri_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapri_s002_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapvx_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapwd_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\FGW\EDF\v2.0.1_new\epilepsy\aaaaapwd_s001_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Number of EDF files with 250 Hz sampling frequency: 386
# Number of EDF files with 120 Hz sampling frequency: 0

# %%
import os
import mne

def count_files_by_all_sampling_frequencies(edf_dir):
    sfreq_counts = {}
    unique_frequencies = set()

    for file in os.listdir(edf_dir):
        if file.endswith('.edf'):
            raw_data = mne.io.read_raw_edf(os.path.join(edf_dir, file), preload=False, verbose=False)
            sfreq = raw_data.info['sfreq']
            unique_frequencies.add(sfreq)

            # Update the count for this sampling frequency
            if sfreq in sfreq_counts:
                sfreq_counts[sfreq] += 1
            else:
                sfreq_counts[sfreq] = 1

    return sfreq_counts, unique_frequencies

# Example usage with output printing
edf_directory = 'D:/FGW/EDF/v2.0.1_new/epilepsy/'
sfreq_counts, unique_frequencies = count_files_by_all_sampling_frequencies(edf_directory)

print("Sampling frequencies and their file counts:")
for sfreq, count in sfreq_counts.items():
    print(f"{sfreq} Hz: {count} files")

print("\nUnique sampling frequencies in the dataset:")
for freq in unique_frequencies:
    print(f"{freq} Hz")
# Out:
# Sampling frequencies and their file counts:
# 250.0 Hz: 386 files
# 256.0 Hz: 1144 files
# 1000.0 Hz: 17 files
# 512.0 Hz: 168 files
# 400.0 Hz: 70 files
#
# Unique sampling frequencies in the dataset:
# 256.0 Hz
# 512.0 Hz
# 1000.0 Hz
# 400.0 Hz
# 250.0 Hz

# %%
import os
import mne

def count_files_by_all_sampling_frequencies(edf_dir):
    sfreq_counts = {}
    unique_frequencies = set()

    for file in os.listdir(edf_dir):
        if file.endswith('.edf'):
            raw_data = mne.io.read_raw_edf(os.path.join(edf_dir, file), preload=False, verbose=False)
            sfreq = raw_data.info['sfreq']
            unique_frequencies.add(sfreq)

            # Update the count for this sampling frequency
            if sfreq in sfreq_counts:
                sfreq_counts[sfreq] += 1
            else:
                sfreq_counts[sfreq] = 1

    return sfreq_counts, unique_frequencies

# Example usage with output printing
edf_directory = 'D:/FGW/EDF/v2.0.1_new/no_epilepsy/'
sfreq_counts, unique_frequencies = count_files_by_all_sampling_frequencies(edf_directory)

print("Sampling frequencies and their file counts:")
for sfreq, count in sfreq_counts.items():
    print(f"{sfreq} Hz: {count} files")

print("\nUnique sampling frequencies in the dataset:")
for freq in unique_frequencies:
    print(f"{freq} Hz")
# Out:
# Sampling frequencies and their file counts:
# 250.0 Hz: 295 files
# 256.0 Hz: 210 files
# 1000.0 Hz: 3 files
# 400.0 Hz: 5 files
#
# Unique sampling frequencies in the dataset:
# 256.0 Hz
# 1000.0 Hz
# 250.0 Hz
# 400.0 Hz

# %%
import os
import mne

def count_files_by_sampling_frequencies_and_electrodes(edf_dir):
    sfreq_counts = {}
    electrode_counts = {}

    for file in os.listdir(edf_dir):
        if file.endswith('.edf'):
            raw_data = mne.io.read_raw_edf(os.path.join(edf_dir, file), preload=False, verbose=False)
            sfreq = raw_data.info['sfreq']
            num_electrodes = len(raw_data.info['ch_names'])

            # Count files by sampling frequency
            if sfreq in sfreq_counts:
                sfreq_counts[sfreq] += 1
            else:
                sfreq_counts[sfreq] = 1

            # Count files by number of electrodes
            if num_electrodes in electrode_counts:
                electrode_counts[num_electrodes] += 1
            else:
                electrode_counts[num_electrodes] = 1

    return sfreq_counts, electrode_counts

# Example usage with output printing
edf_directory = 'D:/FGW/EDF/v2.0.1_new/epilepsy/'
sfreq_counts, electrode_counts = count_files_by_sampling_frequencies_and_electrodes(edf_directory)

# Sort dictionaries by keys (frequency and electrode count)
sorted_sfreq_counts = dict(sorted(sfreq_counts.items()))
sorted_electrode_counts = dict(sorted(electrode_counts.items()))

print("Sampling frequencies and their file counts (sorted by frequency):")
for sfreq, count in sorted_sfreq_counts.items():
    print(f"{sfreq} Hz: {count} files")

print("\nElectrode counts and their file counts (sorted by electrode count):")
for num_electrodes, count in sorted_electrode_counts.items():
    print(f"{num_electrodes} electrodes: {count} files")
# Out:
# Sampling frequencies and their file counts (sorted by frequency):
# 250.0 Hz: 386 files
# 256.0 Hz: 1144 files
# 400.0 Hz: 70 files
# 512.0 Hz: 168 files
# 1000.0 Hz: 17 files
#
# Electrode counts and their file counts (sorted by electrode count):
# 17 electrodes: 2 files
# 18 electrodes: 6 files
# 27 electrodes: 152 files
# 28 electrodes: 104 files
# 29 electrodes: 90 files
# 30 electrodes: 154 files
# 31 electrodes: 152 files
# 32 electrodes: 158 files
# 33 electrodes: 120 files
# 34 electrodes: 583 files
# 35 electrodes: 19 files
# 36 electrodes: 159 files
# 41 electrodes: 86 files

# %%
def count_files_by_sampling_frequencies_and_electrodes(edf_dir):
    sfreq_counts = {}
    electrode_counts = {}

    for file in os.listdir(edf_dir):
        if file.endswith('.edf'):
            raw_data = mne.io.read_raw_edf(os.path.join(edf_dir, file), preload=False, verbose=False)
            sfreq = raw_data.info['sfreq']
            num_electrodes = len(raw_data.info['ch_names'])

            # Count files by sampling frequency
            if sfreq in sfreq_counts:
                sfreq_counts[sfreq] += 1
            else:
                sfreq_counts[sfreq] = 1

            # Count files by number of electrodes
            if num_electrodes in electrode_counts:
                electrode_counts[num_electrodes] += 1
            else:
                electrode_counts[num_electrodes] = 1

    return sfreq_counts, electrode_counts

# Example usage with output printing
edf_directory = 'D:/FGW/EDF/v2.0.1_new/no_epilepsy/'
sfreq_counts, electrode_counts = count_files_by_sampling_frequencies_and_electrodes(edf_directory)

# Sort dictionaries by keys (frequency and electrode count)
sorted_sfreq_counts = dict(sorted(sfreq_counts.items()))
sorted_electrode_counts = dict(sorted(electrode_counts.items()))

print("Sampling frequencies and their file counts (sorted by frequency):")
for sfreq, count in sorted_sfreq_counts.items():
    print(f"{sfreq} Hz: {count} files")

print("\nElectrode counts and their file counts (sorted by electrode count):")
for num_electrodes, count in sorted_electrode_counts.items():
    print(f"{num_electrodes} electrodes: {count} files")
# Out:
# Sampling frequencies and their file counts (sorted by frequency):
# 250.0 Hz: 295 files
# 256.0 Hz: 210 files
# 400.0 Hz: 5 files
# 1000.0 Hz: 3 files
#
# Electrode counts and their file counts (sorted by electrode count):
# 27 electrodes: 6 files
# 28 electrodes: 2 files
# 29 electrodes: 11 files
# 30 electrodes: 75 files
# 31 electrodes: 27 files
# 32 electrodes: 45 files
# 33 electrodes: 140 files
# 34 electrodes: 12 files
# 36 electrodes: 155 files
# 41 electrodes: 40 files
